# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('CADASTRO_IES_2020.CSV', encoding='latin1', delimiter=';', error_bad_lines=False)
print(df.head())
# Out:
#    NU_ANO_CENSO NO_REGIAO_IES  CO_REGIAO_IES NO_UF_IES SG_UF_IES  CO_UF_IES  \
# 0          2020         Norte              1  Rondônia        RO         11
# 1          2020         Norte              1  Rondônia        RO         11
# 2          2020         Norte              1  Rondônia        RO         11
# 3          2020         Norte              1  Rondônia        RO         11
# 4          2020         Norte              1  Rondônia        RO         11
#
#   NO_MUNICIPIO_IES  CO_MUNICIPIO_IES  IN_CAPITAL_IES NO_MESORREGIAO_IES  ...  \
# 0        Ariquemes           1100023               0  Leste Rondoniense  ...
# 1        Ariquemes           1100023               0  Leste Rondoniense  ...
# 2           Cacoal           1100049               0  Leste Rondoniense  ...
# 3           Cacoal           1100049               0  Leste Rondoniense  ...
# 4           Cacoal           1100049               0  Leste Rondoniense  ...
#
#    DOC_EX_60_MAIS DOC_EX_BRANCA  DOC_EX_PRETA  DOC_EX_PARDA  DOC_EX_AMARELA  \
# 0               2            18             1             8               0
# 1               3            45             5            17               2
# 2               9           114             2            31               2
# 3               1            30             1             4               0
# 4               0            14             0             7               0
#
#   DOC_EX_INDÍGENA  DOC_EX_COR_ND DOC_EX_BRA DOC_EX_EST  DOC_EX_COM_DEFICIÊNCIA
# 0               0             27         54          0                       0
# 1               0              0         67          2                       0
# 2               0              3        152          0                       0
# 3               0              4         39          0                       0
# 4               0             18         39          0                       0
#
# [5 rows x 81 columns]
# <ipython-input-2-58f9f91d7d5c>:3: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv('CADASTRO_IES_2020.CSV', encoding='latin1', delimiter=';', error_bad_lines=False)

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2457 entries, 0 to 2456
# Data columns (total 81 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   NU_ANO_CENSO                    2457 non-null   int64
#  1   NO_REGIAO_IES                   2457 non-null   object
#  2   CO_REGIAO_IES                   2457 non-null   int64
#  3   NO_UF_IES                       2457 non-null   object
#  4   SG_UF_IES                       2457 non-null   object
#  5   CO_UF_IES                       2457 non-null   int64
#  6   NO_MUNICIPIO_IES                2457 non-null   object
#  7   CO_MUNICIPIO_IES                2457 non-null   int64
#  8   IN_CAPITAL_IES                  2457 non-null   int64
#  9   NO_MESORREGIAO_IES              2457 non-null   object
#  10  CO_MESORREGIAO_IES              2457 non-null   int64
#  11  NO_MICRORREGIAO_IES             2457 non-null   object
#  12  CO_MICRORREGIAO_IES             2457 non-null   int64
#  13  TP_ORGANIZACAO_ACADEMICA        2457 non-null   int64
#  14  TP_CATEGORIA_ADMINISTRATIVA     2457 non-null   int64
#  15  NO_MANTENEDORA                  2457 non-null   object
#  16  CO_MANTENEDORA                  2457 non-null   int64
#  17  NO_IES                          2457 non-null   object
#  18  SG_IES                          2046 non-null   object
#  19  CO_IES                          2457 non-null   int64
#  20  DS_ENDERECO_IES                 2457 non-null   object
#  21  DS_NUMERO_ENDERECO_IES          2456 non-null   object
#  22  DS_COMPLEMENTO_ENDERECO_IES     2456 non-null   object
#  23  NO_BAIRRO_IES                   2457 non-null   object
#  24  NU_CEP_IES                      2413 non-null   float64
#  25  QT_TEC_TOTAL                    2457 non-null   int64
#  26  QT_TEC_FUNDAMENTAL_INCOMP_FEM   2457 non-null   int64
#  27  QT_TEC_FUNDAMENTAL_INCOMP_MASC  2457 non-null   int64
#  28  QT_TEC_FUNDAMENTAL_COMP_FEM     2457 non-null   int64
#  29  QT_TEC_FUNDAMENTAL_COMP_MASC    2457 non-null   int64
#  30  QT_TEC_MEDIO_FEM                2457 non-null   int64
#  31  QT_TEC_MEDIO_MASC               2457 non-null   int64
#  32  QT_TEC_SUPERIOR_FEM             2457 non-null   int64
#  33  QT_TEC_SUPERIOR_MASC            2457 non-null   int64
#  34  QT_TEC_ESPECIALIZACAO_FEM       2457 non-null   int64
#  35  QT_TEC_ESPECIALIZACAO_MASC      2457 non-null   int64
#  36  QT_TEC_MESTRADO_FEM             2457 non-null   int64
#  37  QT_TEC_MESTRADO_MASC            2457 non-null   int64
#  38  QT_TEC_DOUTORADO_FEM            2457 non-null   int64
#  39  QT_TEC_DOUTORADO_MASC           2457 non-null   int64
#  40  IN_ACESSO_PORTAL_CAPES          2457 non-null   int64
#  41  IN_ACESSO_OUTRAS_BASES          2457 non-null   int64
#  42  IN_ASSINA_OUTRA_BASE            2457 non-null   int64
#  43  IN_REPOSITORIO_INSTITUCIONAL    2457 non-null   int64
#  44  IN_BUSCA_INTEGRADA              2457 non-null   int64
#  45  IN_SERVICO_INTERNET             2457 non-null   int64
#  46  IN_PARTICIPA_REDE_SOCIAL        2457 non-null   int64
#  47  IN_CATALOGO_ONLINE              2457 non-null   int64
#  48  QT_PERIODICO_ELETRONICO         2457 non-null   int64
#  49  QT_LIVRO_ELETRONICO             2457 non-null   int64
#  50  QT_DOCENTE_TOTAL                2457 non-null   int64
#  51  QT_DOCENTE_EXE                  2457 non-null   int64
#  52  DOC_EX_FEMI                     2457 non-null   int64
#  53  DOC_EX_MASC                     2457 non-null   int64
#  54  DOC_EX_SEM_GRAD                 2457 non-null   int64
#  55  DOC_EX_GRAD                     2457 non-null   int64
#  56  DOC_EX_ESP                      2457 non-null   int64
#  57  DOC_EX_MEST                     2457 non-null   int64
#  58  DOC_EX_DOUT                     2457 non-null   int64
#  59  DOC_EX_INT                      2457 non-null   int64
#  60  DOC_EX_INT_DE                   2457 non-null   int64
#  61  DOC_EX_INT_SEM_DE               2457 non-null   int64
#  62  DOC_EX_PARC                     2457 non-null   int64
#  63  DOC_EX_HOR                      2457 non-null   int64
#  64  DOC_EX_0_29                     2457 non-null   int64
#  65  DOC_EX_30_34                    2457 non-null   int64
#  66  DOC_EX_35_39                    2457 non-null   int64
#  67  DOC_EX_40_44                    2457 non-null   int64
#  68  DOC_EX_45_49                    2457 non-null   int64
#  69  DOC_EX_50_54                    2457 non-null   int64
#  70  DOC_EX_55_59                    2457 non-null   int64
#  71  DOC_EX_60_MAIS                  2457 non-null   int64
#  72  DOC_EX_BRANCA                   2457 non-null   int64
#  73  DOC_EX_PRETA                    2457 non-null   int64
#  74  DOC_EX_PARDA                    2457 non-null   int64
#  75  DOC_EX_AMARELA                  2457 non-null   int64
#  76  DOC_EX_INDÍGENA                 2457 non-null   int64
#  77  DOC_EX_COR_ND                   2457 non-null   int64
#  78  DOC_EX_BRA                      2457 non-null   int64
#  79  DOC_EX_EST                      2457 non-null   int64
#  80  DOC_EX_COM_DEFICIÊNCIA          2457 non-null   int64
# dtypes: float64(1), int64(67), object(13)
# memory usage: 1.5+ MB
# None

# %%
print("Analise exploratoria:")
print("Total de linhas: ", len(df))
print("Resumo estatistico:\n", df.describe())
print("\n")
# Out:
# Analise exploratoria:
# Total de linhas:  2457
# Resumo estatistico:
#         NU_ANO_CENSO  CO_REGIAO_IES    CO_UF_IES  CO_MUNICIPIO_IES  \
# count        2457.0    2457.000000  2457.000000      2.457000e+03
# mean         2020.0       2.994709    33.476190      3.365560e+06
# std             0.0       1.052941     9.622577      9.629679e+05
# min          2020.0       1.000000    11.000000      1.100023e+06
# 25%          2020.0       2.000000    29.000000      2.909208e+06
# 50%          2020.0       3.000000    33.000000      3.306305e+06
# 75%          2020.0       4.000000    41.000000      4.106407e+06
# max          2020.0       5.000000    53.000000      5.300108e+06
#
#        IN_CAPITAL_IES  CO_MESORREGIAO_IES  CO_MICRORREGIAO_IES  \
# count     2457.000000         2457.000000          2457.000000
# mean         0.348392            5.836793            23.398860
# std          0.476558            4.304170            18.938151
# min          0.000000            1.000000             1.000000
# 25%          0.000000            3.000000             9.000000
# 50%          0.000000            5.000000            18.000000
# 75%          1.000000            7.000000            32.000000
# max          1.000000           15.000000            66.000000
#
#        TP_ORGANIZACAO_ACADEMICA  TP_CATEGORIA_ADMINISTRATIVA  CO_MANTENEDORA  \
# count               2457.000000                  2457.000000     2457.000000
# mean                   2.720798                     4.117623     6170.891738
# std                    0.634406                     1.039725     7016.440056
# min                    1.000000                     1.000000        1.000000
# 25%                    3.000000                     4.000000      611.000000
# 50%                    3.000000                     4.000000     1827.000000
# 75%                    3.000000                     5.000000    15514.000000
# max                    5.000000                     7.000000    18035.000000
#
#        ...  DOC_EX_60_MAIS  DOC_EX_BRANCA  DOC_EX_PRETA  DOC_EX_PARDA  \
# count  ...     2457.000000    2457.000000   2457.000000   2457.000000
# mean   ...       17.485958      81.145299      3.253561     22.127391
# std    ...       68.097015     228.373504     10.386603     59.115140
# min    ...        0.000000       0.000000      0.000000      0.000000
# 25%    ...        1.000000      10.000000      0.000000      2.000000
# 50%    ...        3.000000      22.000000      1.000000      6.000000
# 75%    ...       11.000000      61.000000      2.000000     16.000000
# max    ...     1766.000000    5352.000000    217.000000    821.000000
#
#        DOC_EX_AMARELA  DOC_EX_INDÍGENA  DOC_EX_COR_ND   DOC_EX_BRA  \
# count     2457.000000      2457.000000    2457.000000  2457.000000
# mean         1.531543         0.188848      40.833130   147.291819
# std          6.697446         0.802169     192.527698   363.420377
# min          0.000000         0.000000       0.000000     0.000000
# 25%          0.000000         0.000000       1.000000    19.000000
# 50%          0.000000         0.000000       3.000000    42.000000
# 75%          1.000000         0.000000      14.000000   113.000000
# max        160.000000        13.000000    3221.000000  5623.000000
#
#         DOC_EX_EST  DOC_EX_COM_DEFICIÊNCIA
# count  2457.000000             2457.000000
# mean      1.787953                0.593000
# std      10.738347                2.561857
# min       0.000000                0.000000
# 25%       0.000000                0.000000
# 50%       0.000000                0.000000
# 75%       1.000000                0.000000
# max     283.000000               71.000000
#
# [8 rows x 68 columns]

# %%
print("Análise exploratória:")
print("Total de linhas: ", len(df))
print("\nResumo estatístico por região:")
regiao_stats = df.groupby('NO_REGIAO_IES').describe()
print(regiao_stats)
# Out:
# Análise exploratória:
# Total de linhas:  2457
#
# Resumo estatístico por região:
#               NU_ANO_CENSO                                               \
#                      count    mean  std     min     25%     50%     75%
# NO_REGIAO_IES
# Centro-Oeste         264.0  2020.0  0.0  2020.0  2020.0  2020.0  2020.0
# Nordeste             552.0  2020.0  0.0  2020.0  2020.0  2020.0  2020.0
# Norte                184.0  2020.0  0.0  2020.0  2020.0  2020.0  2020.0
# Sudeste             1078.0  2020.0  0.0  2020.0  2020.0  2020.0  2020.0
# Sul                  379.0  2020.0  0.0  2020.0  2020.0  2020.0  2020.0
#
#                       CO_REGIAO_IES       ... DOC_EX_EST         \
#                   max         count mean  ...        75%    max
# NO_REGIAO_IES                             ...
# Centro-Oeste   2020.0         264.0  5.0  ...        1.0  152.0
# Nordeste       2020.0         552.0  2.0  ...        0.0  119.0
# Norte          2020.0         184.0  1.0  ...        1.0   67.0
# Sudeste        2020.0        1078.0  3.0  ...        1.0  283.0
# Sul            2020.0         379.0  4.0  ...        1.0   89.0
#
#               DOC_EX_COM_DEFICIÊNCIA                                          \
#                                count      mean       std  min  25%  50%  75%
# NO_REGIAO_IES
# Centro-Oeste                   264.0  0.412879  1.150295  0.0  0.0  0.0  0.0
# Nordeste                       552.0  0.429348  1.616187  0.0  0.0  0.0  0.0
# Norte                          184.0  0.798913  5.387478  0.0  0.0  0.0  0.0
# Sudeste                       1078.0  0.515770  1.863302  0.0  0.0  0.0  0.0
# Sul                            379.0  1.076517  3.692829  0.0  0.0  0.0  1.0
#
#
#                 max
# NO_REGIAO_IES
# Centro-Oeste    9.0
# Nordeste       16.0
# Norte          71.0
# Sudeste        24.0
# Sul            58.0
#
# [5 rows x 544 columns]

# %%
# Gráfico instituições p/ região
contagem_regioes = df['NO_REGIAO_IES'].value_counts()
plt.figure(figsize=(10, 6))
plt.bar(contagem_regioes.index, contagem_regioes.values, color=['skyblue', 'orange', 'purple', 'fireBrick', 'green'])
plt.xlabel('Região')
plt.ylabel('Quantidade de Instituições')
plt.title('Distribuição de Instituições por Região')
plt.savefig('distribuicao_regiao.png')
plt.show()

# %%
print("Análise exploratória por raça/cor:")
print("Total de linhas: ", len(df))
print("\nResumo estatístico das colunas de raça/cor:")
raca_stats = df[['DOC_EX_BRANCA', 'DOC_EX_PRETA', 'DOC_EX_PARDA', 'DOC_EX_AMARELA', 'DOC_EX_INDÍGENA']].describe()
print(raca_stats)
# Out:
# Análise exploratória por raça/cor:
# Total de linhas:  2457
#
# Resumo estatístico das colunas de raça/cor:
#        DOC_EX_BRANCA  DOC_EX_PRETA  DOC_EX_PARDA  DOC_EX_AMARELA  \
# count    2457.000000   2457.000000   2457.000000     2457.000000
# mean       81.145299      3.253561     22.127391        1.531543
# std       228.373504     10.386603     59.115140        6.697446
# min         0.000000      0.000000      0.000000        0.000000
# 25%        10.000000      0.000000      2.000000        0.000000
# 50%        22.000000      1.000000      6.000000        0.000000
# 75%        61.000000      2.000000     16.000000        1.000000
# max      5352.000000    217.000000    821.000000      160.000000
#
#        DOC_EX_INDÍGENA
# count      2457.000000
# mean          0.188848
# std           0.802169
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max          13.000000

# %%
# Gráfico raça/cor
racas = ['DOC_EX_BRANCA', 'DOC_EX_PRETA', 'DOC_EX_PARDA', 'DOC_EX_AMARELA', 'DOC_EX_INDÍGENA']
raca_labels = ['Branca', 'Preta', 'Parda', 'Amarela', 'Indígena']
quantidade_racas = df[racas].sum()
plt.figure(figsize=(10, 6))
plt.bar(raca_labels, quantidade_racas, color='salmon')
plt.xlabel('Raça/Cor')
plt.ylabel('Quantidade de Docentes')
plt.title('Distribuição de Raça/Cor dos Docentes')
plt.savefig('distribuicao_raca_cor.png')
plt.show()

# %%
print("Análise exploratória por gênero:")
print("Total de linhas: ", len(df))
print("\nResumo estatístico das colunas de gênero:")
genero_stats = df[['DOC_EX_FEMI', 'DOC_EX_MASC']].describe()
print(genero_stats)
# Out:
# Análise exploratória por gênero:
# Total de linhas:  2457
#
# Resumo estatístico das colunas de gênero:
#        DOC_EX_FEMI  DOC_EX_MASC
# count  2457.000000  2457.000000
# mean     69.675214    79.404558
# std     170.409964   203.836813
# min       0.000000     0.000000
# 25%       8.000000    10.000000
# 50%      19.000000    23.000000
# 75%      53.000000    58.000000
# max    2667.000000  3607.000000

# %%
# Gráfico docentes p/ gênero
generos = ['DOC_EX_FEMI', 'DOC_EX_MASC']
genero_labels = ['Feminino', 'Masculino']
quantidade_docentes = df[generos].sum()
plt.figure(figsize=(10, 6))
plt.pie(quantidade_docentes, labels=genero_labels, colors=['cyan', 'gold'], autopct='%1.1f%%',  labeldistance=0.7)
plt.axis('equal')
plt.title('Quantidade de Docentes por Gênero')
plt.savefig('quantidade_docentes_genero.png')
plt.show()

# %%
### Começa PDF Aqui ####
# !pip install fpdf2
from fpdf import FPDF

class PDF(FPDF):
    def chapter_title(self, title):
        self.set_left_margin(20)
        self.set_right_margin(20)
        self.set_font('Arial', 'B', 15)
        self.ln(15)
        self.cell(0, 10, title, 0, 1, 'L')
        self.ln(5)

    def chapter_body(self, body):
        self.set_font('Arial', '', 12)
        self.multi_cell(0, 6, body)
        self.ln()

    def add_image(self, image_path):
        self.image(image_path, x=10, y=None, w=180)

pdf = PDF()
pdf.add_page()

# pdf- Gráfico instituições p/ região
pdf.chapter_title('Distribuição de Instituições por Região')
pdf.chapter_body('A análise da distribuição das instituições de ensino superior por região nos traz uma perspectiva interessante. Ao observar o gráfico, é notável que a maioria das faculdades e universidades se concentra na região Sudeste do Brasil. Isso se deve, em grande parte, ao fato de que as primeiras universidades e instituições de ensino superior do país surgiram nessa área. Essas instituições pioneiras desempenharam um papel fundamental no desenvolvimento educacional nas regiões Sul e Sudeste, contribuindo para a construção de uma sólida base educacional nessas localidades.')
pdf.add_image('distribuicao_regiao.png')

pdf.add_page()

# pdf- Gráfico raça/cor 
pdf.chapter_title('Distribuição de Raça/Cor dos Docentes')
pdf.chapter_body('O gráfico exibe a distribuição de docentes com diferentes origens étnicas, abrangendo as categorias de Branca, Preta, Parda, Amarela e Indígena. Ao longo de grande parte da história do país, as oportunidades educacionais foram historicamente limitadas para grupos étnicos minoritários, como indígenas e afrodescendentes. Isso resultou em um número significativamente menor de indivíduos dessas origens buscando carreiras no ensino superior e, consequentemente, contribuindo como professores. É notável e, ao mesmo tempo, um lembrete da necessidade contínua de promover a diversidade e inclusão no ensino superior, com a esperança de que, com o tempo, possamos reverter essas disparidades.')
pdf.add_image('distribuicao_raca_cor.png')

pdf.add_page()

# pdf- Gráfico docentes p/ gênero
pdf.chapter_title('Quantidade de Docentes por Gênero')
pdf.chapter_body('Olhando para a quantidade de professores nas universidades e faculdades, percebe-se algo interessante sobre a igualdade de gênero na educação. No passado, as oportunidades de educação para as mulheres eram limitadas, o que levava a menos mulheres escolhendo carreiras acadêmicas e de ensino. No entanto, hoje em dia, estamos vendo uma mudança gradual. As mulheres estão cada vez mais ocupando posições nas instituições de ensino superior, o que é um sinal positivo de progresso em direção à igualdade de gênero. Isso mostra que as mulheres estão conquistando seu espaço na educação superior e contribuindo de forma significativa.')
pdf.add_image('quantidade_docentes_genero.png')

pdf.output('relatorio_analise.pdf')
# Out:
# Requirement already satisfied: fpdf2 in /usr/local/lib/python3.10/dist-packages (2.7.5)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.10/dist-packages (from fpdf2) (0.7.1)
# Requirement already satisfied: Pillow!=9.2.*,>=6.2.2 in /usr/local/lib/python3.10/dist-packages (from fpdf2) (9.4.0)
# Requirement already satisfied: fonttools>=4.34.0 in /usr/local/lib/python3.10/dist-packages (from fpdf2) (4.42.1)
# <ipython-input-111-a64876a3cdca>:8: UserWarning: Substituting font arial by core font helvetica
#   self.set_font('Arial', 'B', 15)
# <ipython-input-111-a64876a3cdca>:10: DeprecationWarning: The parameter "ln" is deprecated. Instead of ln=1 use new_x=XPos.LMARGIN, new_y=YPos.NEXT.
#   self.cell(0, 10, title, 0, 1, 'L')
# <ipython-input-111-a64876a3cdca>:14: UserWarning: Substituting font arial by core font helvetica
#   self.set_font('Arial', '', 12)
